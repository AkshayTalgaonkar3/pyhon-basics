# %% [markdown]
# Task I

# %%
try:
    numerator = int(input('Enter numerator : '))
    Denominator = int(input('Enter Denominator : '))
    result = numerator/Denominator
except ZeroDivisionError as ex:
    print(f'Error {ex}')
except ValueError as vr:
    print(f'Error {vr}')
else:
    print(result)
finally:
    print('operation complete')
# Out:
# 1.0
# operation complete

# %% [markdown]
# Task II

# %%
prices = [120,350,'abc',500,-200,800]


total = 0
for price in prices:
    try:
        if type(price) != int :
            raise TypeError
        if price < 0:
            raise ValueError
        total = total + price
    except TypeError as ex:
        print(f'value not number {ex}')
    except ValueError as ex:
        print(f'negative valeu not allowed {ex}')
print(total)
# Out:
# value not number
# negative valeu not allowed
# 1770

# %% [markdown]
# Task III

# %%
def check_age(age):
    try:
        
        if age < 1 or age > 120 :
            raise ValueError
    except ValueError as ve:
        print(f'age must be between 1 and 120')

age = int(input('Enter age : ')) 
check_age(age)
age = int(input('Enter age : ')) 
check_age(age)
# Out:
# age must be between 1 and 120

# %% [markdown]
# Task IV

# %%
filename = input('enter filename : ')
try:
    with open(filename,'r') as file:
        for i in range(3):
            line = file.readline()
            print(line)
except FileNotFoundError as fnf:
    print(f'File not found {fnf}')
except PermissionError as pe:
    print(f'File not found {pe}')
finally:
    print('file operation attempted')
# Out:
# My name is Akshay
#
# I am a Java dev
#
# I stay at Mumbai
#
# file operation attempted

# %% [markdown]
# Task V

# %%
cart = []
val = ''
while val != 'q':
    try:
        val = input('Enter value : ')
        if val.lower() == 'q':
            break
        val = float(val)
        if val < 0:
            raise MyCustomException('negative value')
        cart.append(val)
    except ValueError as ve:
        print(f'value error {ve}')
    except MyCustomException as mce:
        print(f'custom error {mce}')

print('Total Items : 'len(cart)))
# Out:
# value error could not convert string to float: ''
# value error could not convert string to float: 's'
# value error could not convert string to float: 's'
# value error could not convert string to float: 'd'
# value error could not convert string to float: 'r'
# value error could not convert string to float: 't'
# value error could not convert string to float: 'y'
